# %% [markdown]
# # Load processsed data
# df, temps_comp what more? why df_comp?

# %%
import pandas as pd

# %%
from my_functions import overarching_risks,environmental_and_occupational_risks,behavioural_risks,metabolic_risks,wata,pollu,temp,otherenvir,occupation,childfood,tobacco, childabuse, dietary_risks

# %%
temps_comp=pd.read_csv('./data/processed_data/temps_comp.csv')
df=pd.read_csv('./data/processed_data/df.csv')
df_comp=pd.read_csv('./data/processed_data/df_comp.csv')
summary_wide=pd.read_csv('./tables/Supplementary Data File 1.csv')
summary_wide_cons=pd.read_csv('./tables/Supplementary Data File 2.csv')

# %%
pd.set_option('display.float_format', '{:.6f}'.format)

# %%
df[(df['Risk_factor'].isin(tobacco))].groupby(['measure']).mean('val')
# Out:
#            Level    year_gbd   anal_year             val           lower  \
# measure
# DALYs   3.000000 2018.600000 2009.564706 72110133.986135 61647459.246780
# Deaths  3.000000 2018.600000 2009.564706  2666053.314230  2316681.249529
#
#                   upper
# measure
# DALYs   82833961.532185
# Deaths   3020084.653438

# %%
df[(df['Risk_factor'].isin(childabuse))].groupby(['measure']).mean('val')
# Out:
#            Level    year_gbd   anal_year            val          lower  \
# measure
# DALYs   2.750000 2018.851852 2009.987654 5975589.942987 3337259.920561
# Deaths  2.666667 2018.482759 2009.793103   43248.907806   24102.389352
#
#                  upper
# measure
# DALYs   9841928.289186
# Deaths    67937.510515

# %% [markdown]
# ## intext numbers LEVEL 1 RISKS

# %%
temps_comp[(temps_comp['Risk_factor'] == 'Metabolic risks') & (temps_comp['year_gbd'].isin([2013, 2021]))&(temps_comp['measure']=='Deaths')]
# Out:
#      Level      Risk_factor measure  year_gbd  anal_year             val  \
# 136    NaN  Metabolic risks  Deaths      2013       2013 15723000.000000
# 722    NaN  Metabolic risks  Deaths      2021       2021 18562545.855514
#
#               lower           upper  Group Overarching_group
# 136 14719000.000000 16767000.000000  Other   Metabolic risks
# 722 16337592.799454 20590813.154793  Other   Metabolic risks

# %%
temps_comp[(temps_comp['Risk_factor'] == 'Behavioural risks') & (temps_comp['year_gbd'].isin([2017, 2021]))&(temps_comp['measure']=='Deaths')]
# Out:
#        Level        Risk_factor measure  year_gbd  anal_year             val  \
# 447 1.000000  Behavioural risks  Deaths      2017       2017 23800000.000000
# 732      NaN  Behavioural risks  Deaths      2021       2021 19115962.710292
#
#               lower           upper  Group  Overarching_group
# 447 23100000.000000 24600000.000000  Other  Behavioural risks
# 732 14801075.558921 22678617.425391  Other  Behavioural risks

# %%
temps_comp[(temps_comp['Risk_factor'] == 'All risk factors') & (temps_comp['year_gbd'].isin([2013, 2021]))&(temps_comp['measure']=='DALYs')]
# Out:
#      Level       Risk_factor measure  year_gbd  anal_year               val  \
# 143    NaN  All risk factors   DALYs      2013       2013  996554000.000000
# 782    NaN  All risk factors   DALYs      2021       2021 1194160305.997880
#
#                 lower             upper  Group Overarching_group
# 143  927157000.000000 1072340000.000000  Other  All risk factors
# 782 1098926339.228440 1310811109.345070  Other  All risk factors

# %%
temps_comp[(temps_comp['Risk_factor'].isin(['Metabolic risks', 'Environmental/occupational risks'])) & (temps_comp['year_gbd'].isin([2013, 2021]))&(temps_comp['measure']=='DALYs')]
# Out:
#      Level                       Risk_factor measure  year_gbd  anal_year  \
# 144    NaN  Environmental/occupational risks   DALYs      2013       2013
# 193    NaN                   Metabolic risks   DALYs      2013       2013
# 783    NaN  Environmental/occupational risks   DALYs      2021       2021
# 792    NaN                   Metabolic risks   DALYs      2021       2021
#
#                  val            lower            upper  Group  \
# 144 289517000.000000 265778000.000000 312094000.000000  Other
# 193 373817000.000000 343978000.000000 403889000.000000  Other
# 783 416369698.591555 363819533.065228 468501713.147278  Other
# 792 476078739.990901 412470868.224027 541393380.178398  Other
#
#                     Overarching_group
# 144  Environmental/occupational risks
# 193                   Metabolic risks
# 783  Environmental/occupational risks
# 792                   Metabolic risks

# %%
temps_comp[(temps_comp['Risk_factor']=='Behavioural risks') & (temps_comp['year_gbd'].isin([2016,2017,2013, 2021]))&(temps_comp['measure']=='DALYs')]
# Out:
#        Level        Risk_factor measure  year_gbd  anal_year              val  \
# 163      NaN  Behavioural risks   DALYs      2013       2013 717608000.000000
# 389 1.000000  Behavioural risks   DALYs      2016       2016 781103690.000000
# 508 1.000000  Behavioural risks   DALYs      2017       2017 913000000.000000
# 778      NaN  Behavioural risks   DALYs      2021       2021 763258561.843508
#
#                lower            upper  Group  Overarching_group
# 163 667831000.000000 771924000.000000  Other  Behavioural risks
# 389 737052730.000000 830058540.000000  Other  Behavioural risks
# 508 863000000.000000 961000000.000000  Other  Behavioural risks
# 778 649014978.895996 865224121.841111  Other  Behavioural risks

# %% [markdown]
# ## intext numbers LEVEL 2 RISKS

# %%
df_comp[(df_comp['Risk_factor'] == 'Air pollution') & 
    (df_comp['measure'] == 'Deaths') & 
    (df_comp['year_gbd'].isin([2017, 2021]))]
# Out:
#        Level    Risk_factor measure  year_gbd  anal_year            val  \
# 608 2.000000  Air pollution  Deaths      2017       2017 4900000.000000
# 995      NaN  Air pollution  Deaths      2021       2021 8079995.357754
#
#              lower          upper
# 608 4420000.000000 5390000.000000
# 995 6709212.885182 9483055.070014

# %%
df_comp[(df_comp['Risk_factor'] == 'Dietary risks') & 
    (df_comp['measure'] == 'Deaths') & 
    (df_comp['year_gbd'].isin([2013, 2019]))]
# Out:
#      Level    Risk_factor measure  year_gbd  anal_year             val  \
# 176    NaN  Dietary risks  Deaths      2013       2013 11274000.000000
# 791    NaN  Dietary risks  Deaths      2019       2019  7943046.066217
#
#              lower           upper
# 176 9656000.000000 12957000.000000
# 791 6472323.455616  9757376.792491

# %%
df_comp[(df_comp['Risk_factor'] == 'Low physical activity') & 
    (df_comp['measure'] == 'Deaths') & 
    (df_comp['year_gbd'].isin([2013, 2021]))]
# Out:
#       Level            Risk_factor measure  year_gbd  anal_year  \
# 195     NaN  Low physical activity  Deaths      2013       2013
# 1006    NaN  Low physical activity  Deaths      2021       2021
#
#                 val          lower          upper
# 195  2182000.000000 1858000.000000 2555000.000000
# 1006  657618.695735  278741.786774 1058456.233423

# %%
df_comp[(df_comp['Risk_factor'] == 'Air pollution') & 
    (df_comp['measure'] == 'DALYs') & 
    (df_comp['year_gbd'].isin([2017, 2019]))]
# Out:
#        Level    Risk_factor measure  year_gbd  anal_year              val  \
# 688 2.000000  Air pollution   DALYs      2017       2017 147000000.000000
# 852      NaN  Air pollution   DALYs      2019       2019 213284886.633513
#
#                lower            upper
# 688 132000000.000000 162000000.000000
# 852 188894775.428659 239530188.999461

# %%
213284886.633513-147000000.000000
# Out:
# 66284886.633513

# %%
df_comp[(df_comp['Risk_factor'] == 'Dietary risks') & 
    (df_comp['measure'] == 'DALYs') & 
    (df_comp['year_gbd'].isin([2017, 2019]))]
# Out:
#        Level    Risk_factor measure  year_gbd  anal_year              val  \
# 737 2.000000  Dietary risks   DALYs      2017       2017 255000000.000000
# 875      NaN  Dietary risks   DALYs      2019       2019 187695611.722531
#
#                lower            upper
# 737 234000000.000000 274000000.000000
# 875 155915464.870632 225396721.892824

# %%
255000000-187695611.722531
# Out:
# 67304388.27746901

# %%
df_comp[(df_comp['Risk_factor'] == 'Child and maternal malnutrition') & 
    (df_comp['measure'] == 'DALYs') & 
    (df_comp['year_gbd'].isin([2015, 2016]))]
# Out:
#        Level                      Risk_factor measure  year_gbd  anal_year  \
# 394      NaN  Child and maternal malnutrition   DALYs      2015       2015
# 554 2.000000  Child and maternal malnutrition   DALYs      2016       2016
#
#                  val            lower            upper
# 394 172120000.000000 151792000.000000 196176000.000000
# 554 275068980.000000 255117960.000000 296600820.000000

# %%
(275068980.000000-172120000.000000)/1000000
# Out:
# 102.94898

# %% [markdown]
# ## intext numbers LEVEL 3 RISKS

# %%
temps_comp[(temps_comp['Risk_factor']=='Smoking') & (temps_comp['anal_year'].isin([2019,2021]))]
# Out:
#      Level Risk_factor measure  year_gbd  anal_year              val  \
# 564    NaN     Smoking  Deaths      2019       2019   7693367.948221
# 626    NaN     Smoking   DALYs      2019       2019 199794745.476503
# 677    NaN     Smoking  Deaths      2021       2021   6175019.075387
# 739    NaN     Smoking   DALYs      2021       2021 165080664.209595
#
#                lower            upper    Group  Overarching_group
# 564   7158449.614296   8200590.607250  Tobacco  Behavioural risks
# 626 185451306.073709 213815712.326619  Tobacco  Behavioural risks
# 677   5047660.837167   7226384.616746  Tobacco  Behavioural risks
# 739 135430162.197463 193938447.453166  Tobacco  Behavioural risks

# %%
(7693367.948221-6175019.075387)/1000000
# Out:
# 1.5183488728339998

# %%
(199794745.476503-165080664.209595)/1000000
# Out:
# 34.71408126690802

# %%
temps_comp[(temps_comp['Risk_factor']=='Particulate matter pollution') & (temps_comp['anal_year'].isin([2019,2017]))]
# Out:
#        Level                   Risk_factor measure  year_gbd  anal_year  \
# 435 3.000000  Particulate matter pollution  Deaths      2017       2017
# 494 3.000000  Particulate matter pollution   DALYs      2017       2017
# 609      NaN  Particulate matter pollution  Deaths      2019       2019
# 673      NaN  Particulate matter pollution   DALYs      2019       2019
#
#                  val            lower            upper          Group  \
# 435   4580000.000000   4130000.000000   5030000.000000  Air pollution
# 494 143000000.000000 129000000.000000 156000000.000000  Air pollution
# 609   6454962.236974   5718170.178532   7235588.482372  Air pollution
# 673 209689842.874868 185903374.812178 235165660.692867  Air pollution
#
#                     Overarching_group
# 435  Environmental/occupational risks
# 494  Environmental/occupational risks
# 609  Environmental/occupational risks
# 673  Environmental/occupational risks

# %%
temps_comp[(temps_comp['Risk_factor']=='Particulate matter pollution')]
# Out:
#        Level                   Risk_factor measure  year_gbd  anal_year  \
# 435 3.000000  Particulate matter pollution  Deaths      2017       2017
# 494 3.000000  Particulate matter pollution   DALYs      2017       2017
# 609      NaN  Particulate matter pollution  Deaths      2019       2019
# 673      NaN  Particulate matter pollution   DALYs      2019       2019
# 701      NaN  Particulate matter pollution  Deaths      2021       2021
# 766      NaN  Particulate matter pollution   DALYs      2021       2021
#
#                  val            lower            upper          Group  \
# 435   4580000.000000   4130000.000000   5030000.000000  Air pollution
# 494 143000000.000000 129000000.000000 156000000.000000  Air pollution
# 609   6454962.236974   5718170.178532   7235588.482372  Air pollution
# 673 209689842.874868 185903374.812178 235165660.692867  Air pollution
# 701   7833220.915388   6479473.762984   9263395.346069  Air pollution
# 766 231511232.938127 194538892.195336 270855451.370096  Air pollution
#
#                     Overarching_group
# 435  Environmental/occupational risks
# 494  Environmental/occupational risks
# 609  Environmental/occupational risks
# 673  Environmental/occupational risks
# 701  Environmental/occupational risks
# 766  Environmental/occupational risks

# %%
7.8-4.6
# Out:
# 3.2

# %%
(231511232.938127-143000000.000000)/1000000
# Out:
# 88.51123293812701

# %%
temps_comp[(temps_comp['Risk_factor']=='Occupational injuries')]
# Out:
#        Level            Risk_factor measure  year_gbd  anal_year  \
# 42       NaN  Occupational injuries  Deaths      2010       2010
# 86       NaN  Occupational injuries   DALYs      2010       2010
# 105      NaN  Occupational injuries  Deaths      2013       2013
# 161      NaN  Occupational injuries   DALYs      2013       2013
# 217      NaN  Occupational injuries  Deaths      2015       2015
# 273      NaN  Occupational injuries   DALYs      2015       2015
# 329 3.000000  Occupational injuries  Deaths      2016       2016
# 387 3.000000  Occupational injuries   DALYs      2016       2016
# 446 3.000000  Occupational injuries  Deaths      2017       2017
# 506 3.000000  Occupational injuries   DALYs      2017       2017
# 592      NaN  Occupational injuries  Deaths      2019       2019
# 655      NaN  Occupational injuries   DALYs      2019       2019
# 714      NaN  Occupational injuries  Deaths      2021       2021
# 747      NaN  Occupational injuries   DALYs      2021       2021
#
#                 val           lower           upper               Group  \
# 42    481429.000000   363778.000000   639590.000000  Occupational risks
# 86  23444000.000000 17736000.000000 30904000.000000  Occupational risks
# 105   159000.000000   127000.000000   206000.000000  Occupational risks
# 161  9947000.000000  7886000.000000 12927000.000000  Occupational risks
# 217   204000.000000   191000.000000   232000.000000  Occupational risks
# 273 13492000.000000 12006000.000000 15545000.000000  Occupational risks
# 329   335710.000000   328640.000000   343270.000000  Occupational risks
# 387 21774600.000000 19810660.000000 24090160.000000  Occupational risks
# 446   304000.000000   288000.000000   323000.000000  Occupational risks
# 506 21100000.000000 19200000.000000 23500000.000000  Occupational risks
# 592   311490.532760   283714.750716   343372.949868  Occupational risks
# 655 22419935.587021 19842434.548992 25396791.377680  Occupational risks
# 714   480609.339767   452246.387531   507681.149764  Occupational risks
# 747 31859651.364044 29105520.446085 34891501.724888  Occupational risks
#
#                     Overarching_group
# 42   Environmental/occupational risks
# 86   Environmental/occupational risks
# 105  Environmental/occupational risks
# 161  Environmental/occupational risks
# 217  Environmental/occupational risks
# 273  Environmental/occupational risks
# 329  Environmental/occupational risks
# 387  Environmental/occupational risks
# 446  Environmental/occupational risks
# 506  Environmental/occupational risks
# 592  Environmental/occupational risks
# 655  Environmental/occupational risks
# 714  Environmental/occupational risks
# 747  Environmental/occupational risks

# %%
temps_comp[(temps_comp['Risk_factor']=='Smoking') & (temps_comp['anal_year'].isin([2010,2019,2021]))].sort_values(by='measure')
# Out:
#      Level Risk_factor measure  year_gbd  anal_year              val  \
# 57     NaN     Smoking   DALYs      2010       2010 136907000.000000
# 626    NaN     Smoking   DALYs      2019       2019 199794745.476503
# 739    NaN     Smoking   DALYs      2021       2021 165080664.209595
# 13     NaN     Smoking  Deaths      2010       2010   5695349.000000
# 564    NaN     Smoking  Deaths      2019       2019   7693367.948221
# 677    NaN     Smoking  Deaths      2021       2021   6175019.075387
#
#                lower            upper    Group  Overarching_group
# 57  117201000.000000 153778000.000000  Tobacco  Behavioural risks
# 626 185451306.073709 213815712.326619  Tobacco  Behavioural risks
# 739 135430162.197463 193938447.453166  Tobacco  Behavioural risks
# 13    4755779.000000   6421611.000000  Tobacco  Behavioural risks
# 564   7158449.614296   8200590.607250  Tobacco  Behavioural risks
# 677   5047660.837167   7226384.616746  Tobacco  Behavioural risks

# %%
summary_wide[summary_wide['rmu_Deaths']>1]
# Out:
#     Unnamed: 0                 Overarching_group  \
# 4            4                 Behavioural risks
# 6            6                 Behavioural risks
# 7            7                 Behavioural risks
# 8            8                 Behavioural risks
# 9            9                 Behavioural risks
# 10          10                 Behavioural risks
# 11          11                 Behavioural risks
# 13          13                 Behavioural risks
# 17          17                 Behavioural risks
# 18          18                 Behavioural risks
# 20          20                 Behavioural risks
# 21          21                 Behavioural risks
# 27          27                 Behavioural risks
# 28          28                 Behavioural risks
# 36          36  Environmental/occupational risks
# 44          44  Environmental/occupational risks
# 50          50  Environmental/occupational risks
# 51          51  Environmental/occupational risks
# 55          55  Environmental/occupational risks
#
#                                         Group  \
# 4             Child and maternal malnutrition
# 6             Child and maternal malnutrition
# 7             Child and maternal malnutrition
# 8             Child and maternal malnutrition
# 9                               Dietary risks
# 10                              Dietary risks
# 11                              Dietary risks
# 13                              Dietary risks
# 17                              Dietary risks
# 18                              Dietary risks
# 20                              Dietary risks
# 21                              Dietary risks
# 27                  Intimate partner violence
# 28                      Low physical activity
# 36                              Air pollution
# 44                         Occupational risks
# 50                  Other environmental risks
# 51                  Other environmental risks
# 55  Unsafe water, sanitation, and handwashing
#
#                                  Risk_factor  median_Deaths     min_Deaths  \
# 4                            Iron deficiency   60000.000000   20950.000000
# 6                   Suboptimal breastfeeding  169000.000000  101023.100000
# 7                       Vitamin A deficiency   83000.000000   17374.400000
# 8                            Zinc deficiency   29000.000000    1611.600000
# 9   Diet high in \nsugar sweetened beverages  126000.000000   22560.000000
# 10               Diet high in processed meat  304284.400000  130000.000000
# 11                     Diet high in red meat   43000.000000   25000.000000
# 13            Diet high in trans fatty acids  405000.000000   93310.700000
# 17                        Diet low in fruits 2420000.000000 1046014.900000
# 18                       Diet low in legumes  603735.000000  389328.800000
# 20                Diet low in nuts and seeds 2060000.000000  575139.200000
# 21   Diet low in seafood omega-3 fatty acids 1389896.000000  337279.700000
# 27                 Intimate partner violence   86503.300000   61276.900000
# 28                     Low physical activity 1373340.000000  657618.700000
# 36                   Ambient ozone pollution  254000.000000  152434.000000
# 44                  Occupational carcinogens  341997.800000  118097.000000
# 50                             Lead exposure  853000.000000  495000.000000
# 51                 Other environmental risks  945000.000000  558000.000000
# 55                       Unsafe water source 1230000.000000  116126.000000
#
#        max_Deaths  n_estimates_Deaths    mean_Deaths     std_Deaths  ...  \
# 4   199000.000000            7.000000   80028.400000   62101.400000  ...
# 6   544817.000000            7.000000  286520.300000  186849.900000  ...
# 7   233000.000000            7.000000   86309.500000   74442.900000  ...
# 8    97330.000000            7.000000   39548.200000   35087.200000  ...
# 9   299521.000000            7.000000  134574.900000  103294.800000  ...
# 10  840857.000000            7.000000  413575.700000  268734.600000  ...
# 11  895674.900000            7.000000  209931.300000  321597.900000  ...
# 13  644981.000000            7.000000  369741.700000  189096.900000  ...
# 17 4902242.000000            7.000000 2678578.400000 1249475.900000  ...
# 18 1116424.000000            4.000000  678305.700000  314126.300000  ...
# 20 2471823.000000            7.000000 1606607.000000  781309.100000  ...
# 21 1538760.000000            7.000000 1119468.300000  472191.600000  ...
# 27  197000.000000            7.000000  121890.700000   64097.400000  ...
# 28 3183940.000000            7.000000 1584771.500000  865220.400000  ...
# 36  489518.800000            7.000000  311973.600000  131615.700000  ...
# 44  746540.000000            7.000000  383422.900000  193632.200000  ...
# 50 1541908.700000            7.000000  865100.400000  358907.600000  ...
# 51 1624069.100000            7.000000  946179.700000  365311.700000  ...
# 55 1251000.000000            7.000000 1005132.300000  423300.400000  ...
#
#          mad_DALYs     range_DALYs  fold_range_vs_median_DALYs  rmu_DALYs  \
# 4   4586744.900000 21606874.900000                    0.600000   0.500000
# 6   5860250.600000 38397250.600000                    2.600000   1.500000
# 7   3631950.000000 26336244.300000                    3.500000   2.800000
# 8   2387000.000000  8987553.000000                    3.500000   2.500000
# 9   1857561.800000  7773490.000000                    1.700000   1.700000
# 10  6787091.000000 17742960.000000                    1.700000   1.600000
# 11   605670.000000 22613743.800000                   12.200000   3.600000
# 13  3715000.000000 11742241.600000                    1.200000   1.300000
# 17  9997000.000000 76416663.800000                    1.200000   1.200000
# 18  2525941.600000 15146471.800000                    1.200000   1.000000
# 20  1878000.000000 37693903.500000                    0.800000   1.000000
# 21  5148840.000000 25938185.100000                    0.900000   1.100000
# 27  2922674.200000 11218710.000000                    1.300000   1.100000
# 28  8610899.600000 53613039.600000                    2.200000   1.600000
# 36  1276170.000000  6317024.500000                    1.200000   1.200000
# 44  1654983.100000 18001730.000000                    2.400000   2.100000
# 50  4833385.300000 24603550.800000                    1.500000   1.300000
# 51  4739861.600000 25115601.800000                    1.300000   1.200000
# 55 11225000.000000 67350000.000000                    1.100000   1.200000
#
#     cv_DALYs  max_vs_min_DALYs  f_med_DALYs  rcv_m_DALYs  \
# 4   0.200000          1.700000     1.500000     0.200000
# 6   0.600000          5.200000     3.200000     0.600000
# 7   1.000000         10.900000     3.800000     0.700000
# 8   0.900000         61.500000    17.400000     1.400000
# 9   0.600000         11.000000     5.700000     0.600000
# 10  0.600000          6.600000     3.200000     1.000000
# 11  1.300000         19.100000    12.900000     0.500000
# 13  0.500000          5.700000     4.000000     0.600000
# 17  0.400000          3.800000     2.300000     0.200000
# 18  0.500000          2.700000     1.900000     0.300000
# 20  0.500000          3.800000     3.600000     0.100000
# 21  0.400000          4.500000     3.800000     0.300000
# 27  0.400000          3.000000     2.000000     0.500000
# 28  0.600000          4.400000     2.900000     0.500000
# 36  0.400000          3.600000     2.100000     0.400000
# 44  0.700000          7.700000     2.800000     0.300000
# 50  0.400000          3.600000     2.000000     0.400000
# 51  0.400000          3.400000     1.900000     0.400000
# 55  0.400000          9.700000     8.200000     0.300000
#
#             Median Deaths (Min-Max)               Median DALYs (Min-Max)
# 4        60000.0 (20950.0-199000.0)   35849870.0 (31263125.1-52870000.0)
# 6      169000.0 (101023.1-544817.0)    15000000.0 (9139749.4-47537000.0)
# 7        83000.0 (17374.4-233000.0)     7611000.0 (2663755.7-29000000.0)
# 8          29000.0 (1611.6-97330.0)       2580000.0 (148447.0-9136000.0)
# 9       126000.0 (22560.0-299521.0)       4450000.0 (779510.0-8553000.0)
# 10     304284.4 (130000.0-840857.0)    10357091.0 (3196040.0-20939000.0)
# 11       43000.0 (25000.0-895674.9)     1853000.0 (1247330.0-23861073.8)
# 13      405000.0 (93310.7-644981.0)     9875000.0 (2491995.3-14234237.0)
# 17  2420000.0 (1046014.9-4902242.0)  64800000.0 (27678336.2-104095000.0)
# 18    603735.0 (389328.8-1116424.0)    12607225.0 (9162566.8-24309038.5)
# 20   2060000.0 (575139.2-2471823.0)   49411000.0 (13595096.5-51289000.0)
# 21   1389896.0 (337279.7-1538760.0)    28199000.0 (7409654.9-33347840.0)
# 27       86503.3 (61276.9-197000.0)     8497964.2 (5575290.0-16794000.0)
# 28   1373340.0 (657618.7-3183940.0)   24315860.0 (15704960.4-69318000.0)
# 36     254000.0 (152434.0-489518.8)      5073000.0 (2456000.0-8773024.5)
# 44     341997.8 (118097.0-746540.0)     7457983.1 (2681000.0-20682730.0)
# 50    853000.0 (495000.0-1541908.7)    16843000.0 (9287000.0-33890550.8)
# 51    945000.0 (558000.0-1624069.1)   18822000.0 (10673000.0-35788601.8)
# 55   1230000.0 (116126.0-1251000.0)    63900000.0 (7775000.0-75125000.0)
#
# [19 rows x 34 columns]

# %% [markdown]
# ## R/M analysis

# %% [markdown]
# ### Across iteration year comparisons

# %%
summary_wide.rmu_Deaths.median()
# Out:
# 0.7

# %%
print('Median range/median deaths risks 2010-2021: '+str(summary_wide.rmu_Deaths.median())+' ('+str(summary_wide.rmu_Deaths.min())+'-'+str(summary_wide.rmu_Deaths.max())+')',
    '\nMedian range/median daly risks 2010-2021: '+str(summary_wide.rmu_DALYs.median())+' ('+str(summary_wide.rmu_DALYs.min())+'-'+str(summary_wide.rmu_DALYs.max())+')')
# Out:
# Median range/median deaths risks 2010-2021: 0.7 (0.0-4.1)
# Median range/median daly risks 2010-2021: 0.6 (0.0-3.6)

# %%
summary_wide.head(3)
# Out:
#    Unnamed: 0  Overarching_group                            Group  \
# 0           0   All risk factors                            Other
# 1           1  Behavioural risks  Child and maternal malnutrition
# 2           2  Behavioural risks  Child and maternal malnutrition
#
#                        Risk_factor   median_Deaths      min_Deaths  \
# 0                 All risk factors 33421437.000000 30839000.000000
# 1  Child and maternal malnutrition  2654950.700000  1414000.000000
# 2             Child growth failure  1037643.000000   888199.300000
#
#        max_Deaths  n_estimates_Deaths     mean_Deaths     std_Deaths  ...  \
# 0 35000050.000000            6.000000 33169320.700000 1518884.600000  ...
# 1  3190000.000000            6.000000  2419450.900000  716510.200000  ...
# 2  1190000.000000            4.000000  1038371.300000  125178.200000  ...
#
#         mad_DALYs      range_DALYs  fold_range_vs_median_DALYs  rmu_DALYs  \
# 0 74492832.500000 216707691.000000                    0.200000   0.200000
# 1 37336796.700000 154880000.000000                    0.600000   0.600000
# 2  5120037.000000  25938542.900000                    0.300000   0.300000
#
#    cv_DALYs  max_vs_min_DALYs  f_med_DALYs  rcv_m_DALYs  \
# 0  0.100000          1.200000     1.100000     0.100000
# 1  0.300000          1.900000     1.600000     0.200000
# 2  0.100000          1.400000     1.200000     0.100000
#
#               Median Deaths (Min-Max)                   Median DALYs (Min-Max)
# 0  33421437.0 (30839000.0-35000050.0)  1137138013.0 (996554000.0-1213261691.0)
# 1     2654950.7 (1414000.0-3190000.0)    273552858.0 (172120000.0-327000000.0)
# 2      1037643.0 (888199.3-1190000.0)      90479848.0 (74061457.1-100000000.0)
#
# [3 rows x 34 columns]

# %%
# Calculate medians for each group, skipping NaN values
behavioural_risks_median = summary_wide[summary_wide['Overarching_group'] == 'Behavioural risks'].rmu_Deaths.median(skipna=True)
environmental_risks_median = summary_wide[summary_wide['Overarching_group'] == 'Environmental/occupational risks'].rmu_Deaths.median(skipna=True)
metabolic_risks_median = summary_wide[summary_wide['Overarching_group'] == 'Metabolic risks'].rmu_Deaths.median(skipna=True)

# Print the results
print(f"Behavioural risks median R/M: {behavioural_risks_median}")
print(f"Environmental/occupational risks median R/M: {environmental_risks_median}")
print(f"Metabolic risks median R/M: {metabolic_risks_median}")

# Calculate medians for each group, skipping NaN values
behavioural_risks_median = summary_wide[summary_wide['Overarching_group'] == 'Behavioural risks'].rmu_DALYs.median(skipna=True)
environmental_risks_median = summary_wide[summary_wide['Overarching_group'] == 'Environmental/occupational risks'].fold_range_vs_median_DALYs.median(skipna=True)
metabolic_risks_median = summary_wide[summary_wide['Overarching_group'] == 'Metabolic risks'].rmu_DALYs.median(skipna=True)

# Print the results
print(f"Behavioural risks median R/M: {behavioural_risks_median}")
print(f"Environmental/occupational risks median R/M: {environmental_risks_median}")
print(f"Metabolic risks median R/M: {metabolic_risks_median}")
# Out:
# Behavioural risks median R/M: 0.95
# Environmental/occupational risks median R/M: 0.7
# Metabolic risks median R/M: 0.5
# Behavioural risks median R/M: 0.75
# Environmental/occupational risks median R/M: 0.5
# Metabolic risks median R/M: 0.5

# %%
# Sort by 'Overarching_group' first
sorted_summary = summary_wide.sort_values(by='Overarching_group')

# Group by 'Group' and calculate the median for the specified columns
group_medians = sorted_summary.groupby('Group')[['rmu_Deaths', 'rmu_DALYs']].median()

# Display the result
group_medians
# Out:
#                                            rmu_Deaths  rmu_DALYs
# Group
# Air pollution                                0.500000   0.500000
# Child and maternal malnutrition              1.100000   0.550000
# Dietary risks                                1.050000   1.000000
# Drug use                                     1.000000   0.600000
# High LDL cholesterol*                        0.600000   0.700000
# High alcohol use                             0.400000   0.600000
# High body-mass index                         0.400000   0.500000
# High fasting plasma glucose                  0.600000   0.600000
# High systolic blood pressure                 0.100000   0.300000
# Intimate partner violence                    1.100000   1.100000
# Kidney dysfunction*                          0.500000   0.500000
# Low bone mineral density                     0.700000   1.000000
# Low physical activity                        1.600000   1.600000
# Non-optimal temperature                      0.100000   0.000000
# Occupational risks                           1.000000   0.500000
# Other                                        0.200000   0.200000
# Other environmental risks                    1.100000   1.200000
# Tobacco                                      0.350000   0.450000
# Unsafe sex                                   0.500000   0.600000
# Unsafe water, sanitation, and handwashing    0.800000   0.800000

# %% [markdown]
# ### Matched comparisons

# %%
summary_wide_cons[summary_wide_cons['rmu_Deaths']>1.5].Risk_factor.unique()
# Out:
# array(['Iron deficiency', 'Vitamin A deficiency', 'Zinc deficiency',
#        'Diet high in \nsugar sweetened beverages',
#        'Diet high in red meat', 'Diet high in trans fatty acids',
#        'Diet low in fruits', 'Diet low in nuts and seeds',
#        'Low physical activity'], dtype=object)

# %%
# Calculate and print the proportion and count of rows where rmu_Deaths > 1
prop_deaths_gt1 = summary_wide_cons['rmu_Deaths'].gt(1).mean()
count_deaths_gt1 = summary_wide_cons['rmu_Deaths'].gt(1).sum()
print(f'prop >1 fold range Deaths, n: {prop_deaths_gt1}, {count_deaths_gt1}')

# Calculate and print the proportion and count of rows where rmu_DALYs > 1
prop_dalys_gt1 = summary_wide_cons['rmu_DALYs'].gt(1).mean()
count_dalys_gt1 = summary_wide_cons['rmu_DALYs'].gt(1).sum()
print(f'prop >1 fold range DALYs, n: {prop_dalys_gt1}, {count_dalys_gt1}')
# Out:
# prop >1 fold range Deaths, n: 0.1490066225165563, 90
# prop >1 fold range DALYs, n: 0.1390728476821192, 84

# %%
print('Median range/median deaths risks 2010-2021: '+str(summary_wide_cons.rmu_Deaths.median())+' ('+str(summary_wide_cons.rmu_Deaths.min())+'-'+str(summary_wide_cons.rmu_Deaths.max())+')',
    '\nMedian range/median daly risks 2010-2021: '+str(summary_wide_cons.rmu_DALYs.median())+' ('+str(summary_wide_cons.rmu_DALYs.min())+'-'+str(summary_wide_cons.rmu_DALYs.max())+')')
# Out:
# Median range/median deaths risks 2010-2021: 0.36454829328193983 (0.0-2.5810824229773317)
# Median range/median daly risks 2010-2021: 0.3291107969842606 (0.0-2.5256558237360025)

# %%
## IQR for deaths and DALYs
summary_wide_cons['rmu_Deaths'].quantile(0.25), summary_wide_cons['rmu_Deaths'].quantile(0.75)
# Out:
# (0.17751081424297907, 0.7711610755766243)

# %%
summary_wide_cons['rmu_DALYs'].quantile(0.25), summary_wide_cons['rmu_DALYs'].quantile(0.75)
# Out:
# (0.14549279317698363, 0.7251634275470046)
